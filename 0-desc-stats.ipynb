# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visualize

# %%
plt.plot([1,2,3],[2,8,14])
plt.show()

# %%
plt.plot([1,2,3],[2,8,14],'or')
plt.show()
